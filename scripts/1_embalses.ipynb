# %%
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset('taxis')

# %%
import pandas as pd

# %%
df['charges'] = df['total'] - (df['fare'] + df['tip'] + df['tolls'])

# %%
import plotly.express as px

# %%
px.pie( 
    data_frame=df,
    names='fare',
    values='tip'

)

# %%
df.columns
# Out:
# Index(['pickup', 'dropoff', 'passengers', 'distance', 'fare', 'tip', 'tolls',
#        'total', 'color', 'payment', 'pickup_zone', 'dropoff_zone',
#        'pickup_borough', 'dropoff_borough', 'charges'],
#       dtype='object')

# %%
data_total = {
     
 'total_fare': df['fare'].sum(),
    'total_tip': df['tip'].sum(),
    'total_charges': df['charges'].sum(),
    'total_tolls': df['tolls'].sum()
     
     
     }

# %%
data_names = {

 ['fare', 'tip', 'charges', 'tolls']
}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 data_names = {
#       2
#       3  ['fare', 'tip', 'charges', 'tolls']
#       4 }
#
# TypeError: unhashable type: 'list'

# %%
px.pie(
    data_frame=df,
    values = data_names,
    names = data_total)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[178], line 1
# ----> 1 px.pie(
#       2     data_frame=df,
#       3     values = data_names,
#       4     names = data_total)
#
# File ~/miniconda3/lib/python3.12/site-packages/plotly/express/_chart_types.py:1629, in pie(data_frame, names, values, color, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, color_discrete_sequence, color_discrete_map, hover_name, hover_data, custom_data, category_orders, labels, title, template, width, height, opacity, hole)
#    1627 else:
#    1628     layout_patch = {}
# -> 1629 return make_figure(
#    1630     args=locals(),
#    1631     constructor=go.Pie,
#    1632     trace_patch=dict(showlegend=(names is not None), hole=hole),
#    1633     layout_patch=layout_patch,
#    1634 )
#
# ...

# %%
print(total_charges)
# Out:
# 20085.3

# %%
print(total_fare)
print(total_tip)
print(total_tolls)
# Out:
# 84214.87
# 12732.32
# 2092.48

# %%
'''
Estaba intentando crear un diccionario creo, para poner del tiron la variable data_names donde names, pero al final lo hice manual pq era mas sencillo

Quiero que ademas aparezca el valor absoluto de esos porcentajes, tambien el total. 

'''

# %%
fig = px.pie(
    data_frame=df, 
    values=[20085.87, 84214.87, 12732.32, 2092.48],
    names=['charges', 'fare', 'tip', 'tolls'],
    title= 'Distribucion de precios segun fare, charges, tip and tolls' 
)

# %%
fig.update_traces(
    textinfo='percent+value'
)

# %%
fig_1 = px.scatter_geo(
    lat =  [40.4168, 41.3879, 39.4699, 37.3886, 43.2630],
    lon = [-3.7038, 2.1699, -0.3763, -5.9823, -2.9350],
    scope = 'europe',
    center = {"lat": 40.4168, "lon": -3.7038}, #No entiendo por qué aqui si va {}, supongo que es porque hay strings y numeros
 )

# %%
px.scatter_mapbox(
    lat =  [40.4168, 41.3879, 39.4699, 37.3886, 43.2630],
    lon = [-3.7038, 2.1699, -0.3763, -5.9823, -2.9350],
    center = {"lat": 40.4168, "lon": -3.7038},
    mapbox_style='carto-positron',
    zoom= 4


    
)

# %%
'''
Me interesa la columna total 2024
01 es andalucia CCAA, luego va por provincias
eliminar las ultimas columnas 
'''

# %%
df_pop = pd.read_excel('pob_21_24.xlsx', header=6, engine='openpyxl')
# Out:
# /Users/raul/miniconda3/lib/python3.12/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning:
#
# Workbook contains no default style, apply openpyxl's default

# %%
df_pop.dropna(inplace=True) # tb puedo asignarlo df_pop = df.dropna()

# %%
df_pop
# Out:
#                          Total  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0                       2024.0      2023.0      2022.0      2021.0
# 1   Total Nacional  48619695.0  48085361.0  47486727.0  47400798.0
# 2     01 Andalucía   8631862.0   8584147.0   8511167.0   8484804.0
# 3       04 Almería    760964.0    753364.0    739541.0    730430.0
# 4         11 Cádiz   1258730.0   1254866.0   1250545.0   1249873.0
# ..             ...         ...         ...         ...         ...
# 68    26 Rioja, La    324184.0    322282.0    319617.0    319444.0
# 69        18 Ceuta     83179.0     83052.0     83051.0     84071.0
# 70        51 Ceuta     83179.0     83052.0     83051.0     84071.0
# 71      19 Melilla     85985.0     85493.0     84932.0     86450.0
# 72      52 Melilla     85985.0     85493.0     84932.0     86450.0
#
#        Hombres  Unnamed: 6  Unnamed: 7  Unnamed: 8     Mujeres  Unnamed: 10  \
# 0       2024.0      2023.0      2022.0      2021.0      2024.0       2023.0
# ...

# %%
df_prov = pd.read_excel('pob_prov.xlsx', header=5)
# Out:
# /Users/raul/miniconda3/lib/python3.12/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning:
#
# Workbook contains no default style, apply openpyxl's default

# %%
df_prov.dropna(inplace=True)
